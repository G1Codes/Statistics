# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

x = pd.Series([12,25,68,42,113])
y = pd.Series([11,29,58,121,100])

df = pd.DataFrame()

df['x'] = x
df['y'] = y
df
# Out:
#      x    y
# 0   12   11
# 1   25   29
# 2   68   58
# 3   42  121
# 4  113  100

# %% [markdown]
# ## We created an empty df and added x & y as its columns

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 3))

# Plot scatterplots on each axes
ax1.scatter(df['x'], df['x'])
ax2.scatter(df['x'], df['y'])

ax1.set_title("Correlation - " + str(df['x'].corr(df['x'])))
ax2.set_title("Correlation - " + str((df['x']).corr(df['y'])))
# Out:
# Text(0.5, 1.0, 'Correlation - 0.6185423626205997')

# %%
df['x'].corr(df['y'])
# Out:
# 0.6185423626205997

# %% [markdown]
# - ### The correlation of x with itself is 1
# - ### Meanwhile, the correlation of x with y is `0.6185423626205997`

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 3))

# Plot scatterplots on each axes
ax1.scatter(df['x'], df['y'])
ax2.scatter(df['x']*2, df['y'])

ax1.set_title("Correlation - " + str(df['x'].corr(df['y'])))
ax2.set_title("Correlation - " + str((df['x']*2).corr(df['y']*2)))
# Out:
# Text(0.5, 1.0, 'Correlation - 0.6185423626205997')

# %% [markdown]
# #### Even if x & y are multiplied by 2, the correlation wouldn’t change.
